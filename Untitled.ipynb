# %%
# %load_ext autoreload
# %autoreload 2

# %%
import crypto_backend.table as tables
from crypto_backend.trainer import Trainer
trainer = Trainer('BTC')
trainer.load_data()
pred = trainer.prophecy_predict()
pred
# Out:
# 2022-03-08 17:57:26.974293: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-08 17:57:26.974410: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/nibuntu/.pyenv/versions/3.8.12/envs/crypto_backend/lib/python3.8/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# /home/nibuntu/.pyenv/versions/3.8.12/envs/crypto_backend/lib/python3.8/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# ...

# %%
import crypto_backend.utils as utils

# %%
utils.all_grapher(pred,currency='BTC')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 utils.all_grapher(pred,currency='BTC')
#
# File ~/code/lamtrinh259/crypto_backend/crypto_backend/utils.py:218, in all_grapher(input_data, currency)
#     204 d_data = datar.daily_data(odata)
#     205 pred_x = input_data.index[-14:]
#     207 fig2 = go.Figure(data=[
#     208             go.Candlestick(x=d_data.index,
#     209                         open=d_data['open'],
#     210                         high=d_data['high'],
#     211                         low=d_data['low'],
#     212                         close=d_data['close'],
#     213                         name = 'Historical Data'),
#     214             go.Scatter( x=pred_x,
#     215                         y=input_data['Predicted Price'],
#     216                         mode='lines',
# ...
