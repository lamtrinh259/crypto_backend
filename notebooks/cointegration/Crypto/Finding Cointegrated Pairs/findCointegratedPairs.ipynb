# %%
#find all possible pairs
symbols = ['ADA', 'AION', 'ANT', 'ARDR', 'BAT', 'BCC', 'BCH', 'BLZ', 'BNB', 'BNT', 'BTC', 'BTS', 'BUSD', 'CTXC', 'CVC', 'DAI', 'DASH', 'DATA', 'DCR', 'DENT', 'DGB', 'DNT', 'DOGE', 'ENJ', 'EOS', 'ETC', 'ETH', 'FUN', 'GTO', 'GXS', 'ICX', 'IOST', 'IOTA', 'IOTX', 'KMD', 'KNC', 'LEND', 'LINK', 'LRC', 'LSK', 'LTC', 'MANA', 'MCO', 'MITH', 'MKR', 'NANO', 'NEO', 'NMR', 'NPXS', 'NULS', 'OMG', 'ONT', 'QTUM', 'REP', 'RLC', 'SC', 'SNX', 'STORJ', 'STORM', 'STRAT', 'STX', 'THETA', 'TRX', 'TUSD', 'UTK', 'VEN', 'WAN', 'WAVES', 'WTC', 'XLM', 'XMR', 'XRP', 'XTZ', 'XZC', 'ZEC', 'ZEN', 'ZIL', 'ZRX']

def possible_pairs():
        pairs = []
        for asset_1 in symbols:
            for asset_2 in symbols:
                if not asset_1 == asset_2:
                    pairs.append([asset_1, asset_2])
        return pairs

# %%
len(symbols)
# Out:
# 78

# %%
# %time pairs = possible_pairs()
len(pairs)
# Out:
# CPU times: user 6.24 ms, sys: 38 µs, total: 6.28 ms
# Wall time: 4.96 ms
# 6006

# %%
from statsmodels.tsa.stattools import coint
import pandas as pd
from tqdm import tqdm


def cointegrated(series_1, series_2, p_threshold=0.01):
    #return true if significantly cointegrated
    pval = coint(series_1, series_2)[1]
    #print(pval)
    return pval < p_threshold, pval

def get_close_prices(asset_1, asset_2):
    filename_1 = "Folder/{}.csv".format(asset_1)
    df_1 = pd.read_csv(filename_1)
    
    filename_2 = "Folder/{}.csv".format(asset_2)
    df_2 = pd.read_csv(filename_2)
    
    prices_1 = df_1['close']
    prices_2 = df_2['close']
    
    #make sure the prices are equal length
    if len(prices_1) > len(prices_2):
        prices_1 = prices_1[-len(prices_2):]
    elif len(prices_2) > len(prices_1):
        prices_2 = prices_2[-len(prices_1):]
        
    return prices_1, prices_2

def find_coint_pairs(pairs):
    selected_pairs = {}
    
    for idx, pair in tqdm(enumerate(pairs), total=len(pairs)):
        #print(idx,'/',len(pairs))
        #print("finding cointegration of {}\n".format(pair))
        asset_1 = pair[0]
        asset_2 = pair[1]
        
        prices_1, prices_2 = get_close_prices(asset_1, asset_2)
        is_cointegrated, pval = cointegrated(prices_1, prices_2)
        if is_cointegrated:
            #print("Added {}\n".format(pair))
            #print(pval)
            selected_pairs[asset_1+'|'+asset_2] = [asset_1, asset_2, pval]
    return selected_pairs  

selected_pairs = find_coint_pairs(pairs)
# Out:
# 100%|███████████████████████████████████████████████████████████████| 6006/6006 [06:42<00:00, 14.92it/s]

# %%
df = pd.DataFrame.from_dict(selected_pairs)
filename = "Cointegrated Pairs.csv"
df.to_csv(filename, index=False)

# %%
len(df)
# Out:
# 3

# %%
df.head()
# Out:
#     ADA|ANT   ADA|BLZ ADA|DAI  ADA|DATA   ADA|DCR ADA|IOTX   ADA|KMD  \
# 0       ADA       ADA     ADA       ADA       ADA      ADA       ADA
# 1       ANT       BLZ     DAI      DATA       DCR     IOTX       KMD
# 2  0.003559  0.001543     0.0  0.000062  0.008913  0.00448  0.002932
#
#     ADA|LRC  ADA|MANA  ADA|NANO  ...   ZIL|SNX   ZIL|XLM   ZIL|ZEN   ZIL|ZRX  \
# 0       ADA       ADA       ADA  ...       ZIL       ZIL       ZIL       ZIL
# 1       LRC      MANA      NANO  ...       SNX       XLM       ZEN       ZRX
# 2  0.001953  0.000062  0.000937  ...  0.000148  0.000777  0.000007  0.002052
#
#     ZRX|GXS    ZRX|SC ZRX|SNX   ZRX|XLM   ZRX|ZEN   ZRX|ZIL
# 0       ZRX       ZRX     ZRX       ZRX       ZRX       ZRX
# 1       GXS        SC     SNX       XLM       ZEN       ZIL
# 2  0.005159  0.000024     0.0  0.001768  0.000015  0.000655
#
# [3 rows x 720 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Columns: 720 entries, ADA|ANT to ZRX|ZIL
# dtypes: object(720)
# memory usage: 17.0+ KB

# %%
list(df.keys())
# Out:
# ['ADA|ANT',
#  'ADA|BLZ',
#  'ADA|DAI',
#  'ADA|DATA',
#  'ADA|DCR',
#  'ADA|IOTX',
#  'ADA|KMD',
#  'ADA|LRC',
#  'ADA|MANA',
#  'ADA|NANO',
#  'ADA|SC',
#  'ADA|SNX',
#  'ADA|STORJ',
#  'ADA|TRX',
#  'ADA|WAVES',
#  'ADA|WTC',
#  'ADA|XRP',
#  'ADA|ZEN',
#  'ANT|STORJ',
#  'BAT|ARDR',
#  'BAT|DAI',
#  'BAT|DGB',
#  'BAT|ENJ',
#  'BAT|GXS',
#  'BAT|KNC',
#  'BAT|LRC',
#  'BAT|MKR',
#  'BAT|NPXS',
#  'BAT|REP',
#  'BAT|SC',
#  'BAT|SNX',
#  'BAT|VEN',
#  'BAT|ZEN',
#  'BCH|DAI',
#  'BNB|ARDR',
#  'BNB|DATA',
#  'BNB|DCR',
#  'BNB|DGB',
#  'BNB|ENJ',
#  'BNB|GXS',
#  'BNB|LRC',
#  'BNB|MKR',
#  'BNB|NANO',
#  'BNB|REP',
#  'BNB|STORJ',
#  'BNB|WTC',
#  'BNT|LSK',
#  'BTC|ANT',
#  'BTC|BLZ',
#  'BTC|DCR',
#  'BTC|DGB',
#  'BTC|KMD',
#  'BTC|LEND',
#  'BTC|LRC',
#  'BTC|MANA',
#  'BTC|MKR',
#  'BTC|NMR',
#  'BTC|REP',
#  'BTC|SC',
#  'BTC|SNX',
#  'BTC|STORJ',
#  'BTC|STRAT',
#  'BTC|ZEN',
#  'BTS|BNT',
#  'BTS|LSK',
#  'BUSD|ADA',
#  'BUSD|ANT',
#  'BUSD|BAT',
#  'BUSD|BCH',
#  'BUSD|BLZ',
#  'BUSD|BNB',
#  'BUSD|BNT',
#  'BUSD|BTC',
#  'BUSD|BTS',
#  'BUSD|CTXC',
#  'BUSD|CVC',
#  'BUSD|DASH',
#  'BUSD|DCR',
#  'BUSD|DENT',
#  'BUSD|DGB',
#  'BUSD|DNT',
#  'BUSD|DOGE',
#  'BUSD|ENJ',
#  'BUSD|EOS',
#  'BUSD|ETC',
#  'BUSD|ETH',
#  'BUSD|FUN',
#  'BUSD|GTO',
#  'BUSD|ICX',
#  'BUSD|IOST',
#  'BUSD|IOTA',
#  'BUSD|IOTX',
#  'BUSD|KMD',
#  'BUSD|LEND',
#  'BUSD|LINK',
#  'BUSD|LSK',
#  'BUSD|LTC',
#  'BUSD|MANA',
#  'BUSD|MITH',
#  'BUSD|MKR',
#  'BUSD|NANO',
#  'BUSD|NEO',
#  'BUSD|NMR',
#  'BUSD|NPXS',
#  'BUSD|NULS',
#  'BUSD|OMG',
#  'BUSD|ONT',
#  'BUSD|QTUM',
#  'BUSD|RLC',
#  'BUSD|SC',
#  'BUSD|SNX',
#  'BUSD|STORJ',
#  'BUSD|STX',
#  'BUSD|THETA',
#  'BUSD|TRX',
#  'BUSD|TUSD',
#  'BUSD|UTK',
#  'BUSD|WAN',
#  'BUSD|WAVES',
#  'BUSD|XLM',
#  'BUSD|XMR',
#  'BUSD|XRP',
#  'BUSD|XTZ',
#  'BUSD|ZEC',
#  'BUSD|ZEN',
#  'BUSD|ZIL',
#  'BUSD|ZRX',
#  'CTXC|AION',
#  'CTXC|DNT',
#  'CTXC|MANA',
#  'CTXC|STX',
#  'CVC|ANT',
#  'CVC|BLZ',
#  'CVC|KMD',
#  'CVC|MKR',
#  'CVC|NMR',
#  'CVC|STORJ',
#  'DAI|CVC',
#  'DAI|FUN',
#  'DAI|LEND',
#  'DAI|STX',
#  'DAI|UTK',
#  'DASH|DAI',
#  'DASH|DGB',
#  'DASH|GTO',
#  'DASH|LTC',
#  'DASH|MITH',
#  'DASH|MKR',
#  'DASH|SC',
#  'DASH|THETA',
#  'DASH|XLM',
#  'DASH|ZEC',
#  'DASH|ZEN',
#  'DASH|ZIL',
#  'DATA|BCC',
#  'DATA|MCO',
#  'DATA|VEN',
#  'DENT|CVC',
#  'DENT|DCR',
#  'DENT|DGB',
#  'DENT|MANA',
#  'DENT|MKR',
#  'DENT|NPXS',
#  'DENT|SNX',
#  'DENT|STORJ',
#  'DENT|WAN',
#  'DOGE|ADA',
#  'DOGE|ANT',
#  'DOGE|ARDR',
#  'DOGE|BCC',
#  'DOGE|DCR',
#  'DOGE|DGB',
#  'DOGE|ETC',
#  'DOGE|GXS',
#  'DOGE|IOTX',
#  'DOGE|MANA',
#  'DOGE|MKR',
#  'DOGE|NANO',
#  'DOGE|NMR',
#  'DOGE|NPXS',
#  'DOGE|STORJ',
#  'DOGE|THETA',
#  'ENJ|ARDR',
#  'ENJ|BAT',
#  'ENJ|BLZ',
#  'ENJ|BNB',
#  'ENJ|DCR',
#  'ENJ|ETH',
#  'ENJ|GXS',
#  'ENJ|KNC',
#  'ENJ|LRC',
#  'ENJ|MKR',
#  'ENJ|REP',
#  'ENJ|SC',
#  'ENJ|SNX',
#  'ENJ|STORJ',
#  'ENJ|XTZ',
#  'ENJ|ZEN',
#  'ETC|ARDR',
#  'ETC|DATA',
#  'ETC|DGB',
#  'ETC|DOGE',
#  'ETC|GTO',
#  'ETC|GXS',
#  'ETC|IOTX',
#  'ETC|MKR',
#  'ETC|NANO',
#  'ETC|NPXS',
#  'ETC|SC',
#  'ETC|THETA',
#  'ETC|TRX',
#  'ETC|WTC',
#  'ETC|XRP',
#  'ETH|ANT',
#  'ETH|BLZ',
#  'ETH|DATA',
#  'ETH|DGB',
#  'ETH|ENJ',
#  'ETH|KMD',
#  'ETH|MANA',
#  'ETH|NMR',
#  'ETH|SC',
#  'ETH|SNX',
#  'ETH|STORJ',
#  'ETH|VEN',
#  'ETH|WTC',
#  'ETH|ZEN',
#  'GTO|ARDR',
#  'GTO|BAT',
#  'GTO|BNB',
#  'GTO|DASH',
#  'GTO|ENJ',
#  'GTO|ETC',
#  'GTO|GXS',
#  'GTO|IOST',
#  'GTO|IOTA',
#  'GTO|LTC',
#  'GTO|MITH',
#  'GTO|QTUM',
#  'GTO|TRX',
#  'GTO|XMR',
#  'GTO|XRP',
#  'GTO|ZEC',
#  'GXS|ANT',
#  'GXS|BLZ',
#  'GXS|KMD',
#  'GXS|MANA',
#  'GXS|MKR',
#  'GXS|WAN',
#  'ICX|ANT',
#  'ICX|ARDR',
#  'ICX|DGB',
#  'ICX|IOST',
#  'ICX|LINK',
#  'ICX|LRC',
#  'ICX|MKR',
#  'ICX|REP',
#  'ICX|SC',
#  'ICX|SNX',
#  'ICX|XLM',
#  'ICX|ZEC',
#  'ICX|ZEN',
#  'IOST|ANT',
#  'IOST|DGB',
#  'IOST|GXS',
#  'IOST|ICX',
#  'IOST|KNC',
#  'IOST|LRC',
#  'IOST|MKR',
#  'IOST|NMR',
#  'IOST|QTUM',
#  'IOST|REP',
#  'IOST|SC',
#  'IOST|SNX',
#  'IOST|THETA',
#  'IOST|XRP',
#  'IOST|ZEN',
#  'IOTA|DCR',
#  'IOTA|DGB',
#  'IOTA|GTO',
#  'IOTA|GXS',
#  'IOTA|LRC',
#  'IOTA|MKR',
#  'IOTA|NPXS',
#  'IOTA|QTUM',
#  'IOTA|REP',
#  'IOTA|SC',
#  'IOTA|SNX',
#  'IOTA|STORJ',
#  'IOTA|THETA',
#  'IOTA|ZEN',
#  'IOTX|KNC',
#  'IOTX|LRC',
#  'IOTX|REP',
#  'IOTX|STX',
#  'KMD|DAI',
#  'KNC|DAI',
#  'KNC|REP',
#  'LINK|DGB',
#  'LINK|ICX',
#  'LINK|MANA',
#  'LINK|MKR',
#  'LINK|STORJ',
#  'LINK|THETA',
#  'LRC|RLC',
#  'LRC|STX',
#  'LRC|UTK',
#  'LSK|BCC',
#  'LSK|BNT',
#  'LSK|BTS',
#  'LSK|DAI',
#  'LTC|BLZ',
#  'LTC|GTO',
#  'LTC|MKR',
#  'LTC|THETA',
#  'LTC|XLM',
#  'MANA|CTXC',
#  'MANA|DNT',
#  'MCO|BAT',
#  'MCO|BNB',
#  'MCO|BTC',
#  'MCO|DASH',
#  'MCO|DOGE',
#  'MCO|ETH',
#  'MCO|ICX',
#  'MCO|IOTA',
#  'MCO|QTUM',
#  'MCO|TRX',
#  'MCO|XLM',
#  'MCO|XRP',
#  'MCO|ZEC',
#  'MITH|ARDR',
#  'MITH|DASH',
#  'MITH|GTO',
#  'MITH|GXS',
#  'MKR|DAI',
#  'NANO|ADA',
#  'NANO|ARDR',
#  'NANO|BNB',
#  'NANO|ETC',
#  'NANO|KNC',
#  'NANO|LRC',
#  'NANO|QTUM',
#  'NANO|REP',
#  'NANO|SC',
#  'NANO|TRX',
#  'NANO|WAVES',
#  'NANO|XMR',
#  'NANO|XRP',
#  'NANO|ZEN',
#  'NEO|DGB',
#  'NEO|GXS',
#  'NEO|MKR',
#  'NEO|NANO',
#  'NEO|SC',
#  'NEO|SNX',
#  'NEO|THETA',
#  'NEO|VEN',
#  'NEO|ZEN',
#  'NEO|ZIL',
#  'NEO|ZRX',
#  'NPXS|AION',
#  'NPXS|ANT',
#  'NPXS|ARDR',
#  'NPXS|BCH',
#  'NPXS|BLZ',
#  'NPXS|BNT',
#  'NPXS|BTS',
#  'NPXS|BUSD',
#  'NPXS|CTXC',
#  'NPXS|CVC',
#  'NPXS|DASH',
#  'NPXS|DATA',
#  'NPXS|DCR',
#  'NPXS|DENT',
#  'NPXS|DGB',
#  'NPXS|DOGE',
#  'NPXS|ENJ',
#  'NPXS|EOS',
#  'NPXS|FUN',
#  'NPXS|GXS',
#  'NPXS|IOTX',
#  'NPXS|KMD',
#  'NPXS|KNC',
#  'NPXS|LRC',
#  'NPXS|LSK',
#  'NPXS|LTC',
#  'NPXS|MITH',
#  'NPXS|MKR',
#  'NPXS|NANO',
#  'NPXS|NMR',
#  'NPXS|NULS',
#  'NPXS|OMG',
#  'NPXS|ONT',
#  'NPXS|REP',
#  'NPXS|RLC',
#  'NPXS|SC',
#  'NPXS|SNX',
#  'NPXS|STORJ',
#  'NPXS|STX',
#  'NPXS|TRX',
#  'NPXS|TUSD',
#  'NPXS|WTC',
#  'NPXS|XLM',
#  'NPXS|XRP',
#  'NPXS|ZEC',
#  'NPXS|ZEN',
#  'NULS|DASH',
#  'OMG|ARDR',
#  'OMG|CTXC',
#  'OMG|IOTX',
#  'OMG|RLC',
#  'OMG|STX',
#  'OMG|WAVES',
#  'QTUM|ARDR',
#  'QTUM|DATA',
#  'QTUM|DGB',
#  'QTUM|GTO',
#  'QTUM|GXS',
#  'QTUM|IOST',
#  'QTUM|IOTA',
#  'QTUM|MKR',
#  'QTUM|NANO',
#  'QTUM|REP',
#  'QTUM|SC',
#  'QTUM|THETA',
#  'QTUM|TRX',
#  'QTUM|WAVES',
#  'QTUM|WTC',
#  'QTUM|XRP',
#  'QTUM|ZEN',
#  'REP|GTO',
#  'REP|ZEN',
#  'RLC|LRC',
#  'SC|STRAT',
#  'SNX|VEN',
#  'STORM|ADA',
#  'STORM|AION',
#  'STORM|ANT',
#  'STORM|ARDR',
#  'STORM|BAT',
#  'STORM|BCC',
#  'STORM|BCH',
#  'STORM|BLZ',
#  'STORM|BNB',
#  'STORM|BNT',
#  'STORM|BTC',
#  'STORM|BTS',
#  'STORM|BUSD',
#  'STORM|CTXC',
#  'STORM|DASH',
#  'STORM|DATA',
#  'STORM|DCR',
#  'STORM|DENT',
#  'STORM|DGB',
#  'STORM|DNT',
#  'STORM|DOGE',
#  'STORM|ENJ',
#  'STORM|EOS',
#  'STORM|ETC',
#  'STORM|ETH',
#  'STORM|FUN',
#  'STORM|GTO',
#  'STORM|GXS',
#  'STORM|ICX',
#  'STORM|IOST',
#  'STORM|IOTA',
#  'STORM|IOTX',
#  'STORM|KMD',
#  'STORM|KNC',
#  'STORM|LINK',
#  'STORM|LRC',
#  'STORM|LSK',
#  'STORM|LTC',
#  'STORM|MANA',
#  'STORM|MCO',
#  'STORM|MITH',
#  'STORM|MKR',
#  'STORM|NANO',
#  'STORM|NEO',
#  'STORM|NMR',
#  'STORM|NPXS',
#  'STORM|NULS',
#  'STORM|OMG',
#  'STORM|ONT',
#  'STORM|QTUM',
#  'STORM|REP',
#  'STORM|RLC',
#  'STORM|SC',
#  'STORM|SNX',
#  'STORM|STORJ',
#  'STORM|STX',
#  'STORM|THETA',
#  'STORM|TRX',
#  'STORM|TUSD',
#  'STORM|UTK',
#  'STORM|WAN',
#  'STORM|WAVES',
#  'STORM|WTC',
#  'STORM|XLM',
#  'STORM|XMR',
#  'STORM|XRP',
#  'STORM|XTZ',
#  'STORM|XZC',
#  'STORM|ZEC',
#  'STORM|ZEN',
#  'STORM|ZIL',
#  'STORM|ZRX',
#  'STX|DNT',
#  'STX|LRC',
#  'THETA|ANT',
#  'THETA|ARDR',
#  'THETA|BLZ',
#  'THETA|DASH',
#  'THETA|DGB',
#  'THETA|DOGE',
#  'THETA|ETC',
#  'THETA|GXS',
#  'THETA|IOST',
#  'THETA|IOTA',
#  'THETA|KMD',
#  'THETA|KNC',
#  'THETA|LEND',
#  'THETA|LINK',
#  'THETA|LRC',
#  'THETA|MANA',
#  'THETA|MCO',
#  'THETA|NEO',
#  'THETA|NMR',
#  'THETA|QTUM',
#  'THETA|REP',
#  'THETA|SC',
#  'THETA|SNX',
#  'THETA|TRX',
#  'THETA|WAVES',
#  'THETA|XLM',
#  'THETA|XMR',
#  'THETA|ZEN',
#  'TRX|ADA',
#  'TRX|ARDR',
#  'TRX|DGB',
#  'TRX|ENJ',
#  'TRX|ETC',
#  'TRX|GXS',
#  'TRX|NANO',
#  'TRX|QTUM',
#  'TRX|THETA',
#  'TRX|WAVES',
#  'TRX|XRP',
#  'TUSD|ADA',
#  'TUSD|BAT',
#  'TUSD|BCH',
#  'TUSD|BNB',
#  'TUSD|BNT',
#  'TUSD|BTC',
#  'TUSD|BUSD',
#  'TUSD|CTXC',
#  'TUSD|CVC',
#  'TUSD|DAI',
#  'TUSD|DASH',
#  'TUSD|DENT',
#  'TUSD|DOGE',
#  'TUSD|ENJ',
#  'TUSD|EOS',
#  'TUSD|ETC',
#  'TUSD|ETH',
#  'TUSD|FUN',
#  'TUSD|GTO',
#  'TUSD|ICX',
#  'TUSD|IOST',
#  'TUSD|IOTA',
#  'TUSD|IOTX',
#  'TUSD|LINK',
#  'TUSD|LTC',
#  'TUSD|MITH',
#  'TUSD|NANO',
#  'TUSD|NEO',
#  'TUSD|NULS',
#  'TUSD|OMG',
#  'TUSD|ONT',
#  'TUSD|QTUM',
#  'TUSD|RLC',
#  'TUSD|SC',
#  'TUSD|STX',
#  'TUSD|THETA',
#  'TUSD|TRX',
#  'TUSD|WAN',
#  'TUSD|WAVES',
#  'TUSD|XLM',
#  'TUSD|XMR',
#  'TUSD|XRP',
#  'TUSD|XTZ',
#  'TUSD|ZEC',
#  'TUSD|ZIL',
#  'TUSD|ZRX',
#  'VEN|AION',
#  'VEN|ARDR',
#  'VEN|BAT',
#  'VEN|BCC',
#  'VEN|BNT',
#  'VEN|BTC',
#  'VEN|DCR',
#  'VEN|DENT',
#  'VEN|ETH',
#  'VEN|FUN',
#  'VEN|ICX',
#  'VEN|IOST',
#  'VEN|IOTX',
#  'VEN|KNC',
#  'VEN|LEND',
#  'VEN|LTC',
#  'VEN|MKR',
#  'VEN|NANO',
#  'VEN|NEO',
#  'VEN|NMR',
#  'VEN|NPXS',
#  'VEN|OMG',
#  'VEN|QTUM',
#  'VEN|RLC',
#  'VEN|SNX',
#  'VEN|TUSD',
#  'VEN|WAN',
#  'VEN|WTC',
#  'VEN|XMR',
#  'VEN|ZEC',
#  'VEN|ZEN',
#  'VEN|ZIL',
#  'WAN|ANT',
#  'WAN|BLZ',
#  'WAN|DCR',
#  'WAN|DENT',
#  'WAN|DGB',
#  'WAN|KMD',
#  'WAN|MKR',
#  'WAN|NMR',
#  'WAN|SNX',
#  'WAN|STORJ',
#  'WAN|UTK',
#  'WAVES|ADA',
#  'WAVES|BTC',
#  'WAVES|DATA',
#  'WAVES|ETH',
#  'WAVES|GXS',
#  'WAVES|ICX',
#  'WAVES|LTC',
#  'WAVES|NANO',
#  'WAVES|OMG',
#  'WAVES|QTUM',
#  'WAVES|THETA',
#  'WAVES|UTK',
#  'WAVES|WTC',
#  'WAVES|XLM',
#  'WAVES|XRP',
#  'WAVES|ZRX',
#  'XLM|ANT',
#  'XLM|BLZ',
#  'XLM|DAI',
#  'XLM|DCR',
#  'XLM|DGB',
#  'XLM|ICX',
#  'XLM|KMD',
#  'XLM|MANA',
#  'XLM|MKR',
#  'XLM|SC',
#  'XLM|STORJ',
#  'XLM|THETA',
#  'XLM|XMR',
#  'XLM|ZEN',
#  'XLM|ZIL',
#  'XLM|ZRX',
#  'XMR|ARDR',
#  'XMR|DATA',
#  'XMR|GXS',
#  'XMR|THETA',
#  'XMR|WTC',
#  'XMR|XLM',
#  'XRP|ADA',
#  'XRP|ARDR',
#  'XRP|BNB',
#  'XRP|BTC',
#  'XRP|ENJ',
#  'XRP|ETC',
#  'XRP|ETH',
#  'XRP|GTO',
#  'XRP|GXS',
#  'XRP|IOST',
#  'XRP|NANO',
#  'XRP|OMG',
#  'XRP|QTUM',
#  'XRP|THETA',
#  'XRP|TRX',
#  'XRP|UTK',
#  'XRP|WAVES',
#  'ZEC|DAI',
#  'ZEC|DASH',
#  'ZEC|DGB',
#  'ZEC|GTO',
#  'ZEC|GXS',
#  'ZEC|ICX',
#  'ZEC|SC',
#  'ZEC|THETA',
#  'ZEC|XMR',
#  'ZEC|ZEN',
#  'ZEC|ZRX',
#  'ZIL|ANT',
#  'ZIL|ARDR',
#  'ZIL|BLZ',
#  'ZIL|LRC',
#  'ZIL|NMR',
#  'ZIL|SC',
#  'ZIL|SNX',
#  'ZIL|XLM',
#  'ZIL|ZEN',
#  'ZIL|ZRX',
#  'ZRX|GXS',
#  'ZRX|SC',
#  'ZRX|SNX',
#  'ZRX|XLM',
#  'ZRX|ZEN',
#  'ZRX|ZIL']

# %%
 len(list(df.keys()))/len(pairs)
# Out:
# 0.11988011988011989
